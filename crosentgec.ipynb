# %%
! git clone https://github.com/nusnlp/crosentgec.git

# %%
! cp -r crosentgec/* . && rm -r crosentgec

# %%
! bash download_pretrained_crosent.sh

# %%
! bash download.sh

# %%
! mkdir -p data/test/first_test; echo "Hellow , it 's me ." | tee data/test/first_test/first_test.tok.src > data/test/first_test/first_test.tok.ctx

# %%
! apt-get install build-essential checkinstall -y

# %%
! apt-get install -y --fix-missing libreadline-gplv2-dev libncursesw5-dev libssl-dev libsqlite3-dev tk-dev libgdbm-dev libc6-dev libbz2-dev

# %%
! wget -P /usr/src https://www.python.org/ftp/python/2.7.18/Python-2.7.18.tgz

# %%
! tar xzf /usr/src/Python-2.7.18.tgz

# %%
! mv Python-2.7.18 /usr/src/

# %%
! bash /usr/src/Python-2.7.18/configure --enable-optimizations

# %%
! make altinstall

# %%
 ! ./decode.sh first_test models/crosent/model2/checkpoint_best.pt models/dicts

# %%
! cat models/crosent/model2/outputs.checkpoint_best.pt/first_test.out
